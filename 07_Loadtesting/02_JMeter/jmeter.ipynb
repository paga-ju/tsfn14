# %% [markdown]
# ## File Structure
#
# The root folder contains:
# - a `apache-jmeter-5.6.3` subfolder housing the JMeter loadtesting tool, where
#   - `apache-jmeter-5.6.3/bin/jmeter` is the executable file for JMeter.
#   - JMeter is a Java application that requires the Java Runtime Environment (JRE).
# - a `todoapp.jmx` file with a JMeter Test Plan for loadtesting the Microservice application.
# - a `user.properties` file with JMeter settings (not necessary for this exercise).
# - a `Dockerfile` for building and running the JMeter CLI in a Docker container (not necessary for this exercise).
#
# The root folder also contains the Docker Compose and Environment variable files from the previous exercise:
# - `docker-compose.yaml`, which has been slightly modified to reflect the relative paths to the Micriservice folders.
# - `.env`, which hasn't been modified.

# %% [markdown]
# ## JMeter
#
# JMeter (a Java application) is the most popular loadtesting tool.
#
# - Java
#   - JMeter requires Java, so download and install Java or OpenJDK:
#     - Java: https://www.oracle.com/java/technologies/downloads
#     - OpenJDK: https://openjdk.org
#
# - JMeter:
#   - JMeter has already been downloaded and extracted to the folder `apache-jmeter-5.6.3`
#     - Website: https://jmeter.apache.org
#     - Install: https://jmeter.apache.org/download_jmeter.cgi
#
# - JMeter Tutorials:
#   - Quick: https://www.guru99.com/jmeter-performance-testing.html
#   - Full Course: https://www.youtube.com/watch?v=SoW2pBak1_Q
#   - Component Reference: https://jmeter.apache.org/usermanual/component_reference.html
#   - JMeter Load Testing in Azure: https://www.youtube.com/watch?v=kfIS7uO1CPE

# %% [markdown]
# ## JMeter CLI
#
# - JMeter can be used from the commandline, by executing file `apache-jmeter-5.6.3/bin/jmeter`.
#
# - Basic commands:
#   - `jmeter -h`
#     - For JMeter help using the JMeter CLI.
#   - `jmeter -?`
#     - For viewing all parameters that the JMeter CLI accepts.
#   - `jmeter -n -t [JMXTestPlanFile] -l [CSVResultFile] -e -o [ReportsOutputFolder]`
#     - This command wil:
#       - Runs the JMeter Test Plan contained in the JMX file `[JMXTestPlanFile]`.
#       - Store the results logs to the file `[CSVResultFile]`.
#       - Store the results report to the file `[ReportsOutputFolder]`.
#   - `jmeter -g [CSVResultFile] -o [ReportsOutputFolder]`
#     - This command wil:
#       - Create a results report file `[ReportsOutputFolder]` from a result log file [CSVResultFile].

# %% [markdown]
# ## JMeter GUI
#
# - JMeter also comes with a Graphical User Interface (GUI).
# - To start the application, open a separate terminal and run the file: `07_Loadtesting/02_JMeter/apache-jmeter-5.6.3/bin/jmeter`
#
# - Most menu items in the main menu have equivalent toolbar buttons in the toolbar below the main menu.
# - From left to right, these buttons do the following:
#   - Create a new Test Plan.
#   - Create a Test Plan from a templete, e.g. `Building an Advanced Web Test Plan` (choose in combobox in popup window).
#   - Open a Test Plan (a file with a `.jmx` file extension).
#   - Save the current Test Plan (to a file with a `.jmx` file extension).
#   - The next three toolbar buttons are for `cut`, `copy` and `paste`.
#   - The next two toolbar buttons are for expanding and collapsing the tree view of items contained in a Test Plan.
#   - Toggle a Tesp Plan item between `enabled` or `disabled` (a disabled item isn't included when a Test Plan is run).
#   - Run (start) the Test Plan.
#   - Run (start) the Test Plan without any pauses (pauses incldued in a Test Plan are skipped).
#   - Stop a running Test Plan (this will **abruptly kill the threads** running in the Test Plan).
#   - Stop a running Test Plan (this will **gracefully wait for threads to finish** which are running in the Test Plan).
#   - Clear the selected `Listener` (a `Listener` is a Test Plan item that stores results).
#   - Clear the `Listeners` (this will **clear the data from all `Listeners`** in the Test Plan).
#   - The final four toolbar buttons access JMeter's help system (`search`, `reset search`, `function helper`, and `help`).
#     - Clicking the `help` button will open a browser will with help for the currectly selected item in the Test Plan.
# - In the top-right corner you will find information displayed about.
#   - The execution time of the Test Plan (i.e. it shows how long the test has been running).
#   - The number of errors produced by the runnig test.
#     - Clicking the "triangle" icon will display the log in the bottom of the GUI.
#   - The number of threads (users) currently running, and the total amount of threads (users) part of the test (`running/total`).
# - In the left margin, a tree view is shown of the Test Plan with all its child elements (currently there are no child elements).
# - The main working area, in the middle-right of the GUI, displays an editor for the currently selected item in the tree view.
#     - You can rename the `Test Plan` using the `Name` field in the working area, and it will be reflected in the tree view.
#
# <img src="../notebook_images/jmeter_ide.png" width="800" height="500" style="margin:2em" />

# %% [markdown]
# ## Create a Test Plan
#
# Let's recreate the file `todoapp.jmx` in the `02_JMeter` folder using the JMeter GUI.
#
# - Click on `Test Plan` in the tree view
#   - Change `Name` to `Todo Test Plan` in the Editor.
#
# - Right click `Todo Test Plan` -> `Add` -> `Config Element` -> `User Defined Variables`
#   - Click the `Add` button.
#   - Enter `API_VERSION` under `Name` and `v1` under `Value`.
#   - Click the `Add` button.
#   - Set `Name` to `SERVER` and `value` to `localhost`.
#
# - Right click `Todo Test Plan` -> `Add` -> `Threads (Users)` -> `Thread Group`
#   - Set `Name` to `Load Test`.
#   - Set `Number of Threads (users)` to `50`.
#   - Set `Ramp-up period (seconds)` to `5`.
#   - Check `Infinite` next to `Loop Count`-
#   - Check `Same user on each iteration`.
#   - Uncheck `Deplay Thread creation until needed`.
#   - Check `Specify Thread lifetime`
#   - Set `Duraction (seconds)` to `60`.
#   - Set `Startup delay (seconds)` to `1`.
#
# - Right click `Load Test` -> `Add` -> `Config Element` -> `Counter`
#   - Set `Name` to `User Counter`.
#   - Set `Starting value` to `1`.
#   - Set `Increment` to `1`.
#   - Set `Exported Variable Name` to `USER`.
#
# --------------
# Signup Request
# --------------
#
# - Right click `Load Test` -> `Add` -> `Sampler` -> `HTTP Request`
#   - Set `Name` to `Signup`.
#   - Set `Protocol (http)` to `http`.
#   - Set `Server Name or IP` to `${SERVER}`.
#     - `${SERVER}` is the value of the `SERVER` variable we set under `User Defined Variables`.
#   - Set `Port Number` to `5000`.
#   - Choose `HTTP Request` to `POST`.
#   - Set `Path` to `/api/${API_VERSION}/signup`.
#     - `${API_VERSION}` is the value of the `API_VERSION` variable we set under `User Defined Variables`.
#   - Check `Follow Redirects`.
#   - Check `Use Keepalive`.
#   - Click `Body Data` and enter (in the textbox below):
#
#     ```bash
#     { "email": "admin${USER}@ju.se", "password": "abc123" }
#     ```
#
# - Right click `Signup` -> `Add` -> `Config Element` -> `HTTP Header Manager`
#   - Set `Name` to `HTTP Header Content Type`.
#   - Click the `Add` button.
#   - Set `Name` to `Content-Type` and `Value` to `application/json`.
#
# - Right click `Signup` -> `Add` -> `Assertion` -> `Response Assertion`
#   - Set `Name` to `Response Assertion 200`.
#   - Check `Main sample only` under `Apply to`.
#   - Check `Response Code` under `Field to Test`.
#   - Check `Substring` under `Patterns to Test`.
#   - Click the `Add` button.
#   - Enter `200` in the textbox below `Patterns to Test`.
#
# - Right click `Signup` -> `Add` -> `Assertion` -> `JSON Assertion`
#   - Set `Name` to `JSON Assertion Email Exists`.
#   - Set `Assert JSON Path exists` to `.email`.
#   - Check `Additionally assert value`.
#   - Set `Expected Value` to `"admin${USER}@ju.se"`.
#
# - Right click `Signup` -> `Add` -> `Assertion` -> `JSON Assertion`
#   - Set `Name` to `JSON Assertion Token Exists`.
#   - Set `Assert JSON Path exists` to `.token`.
#
# - Right click `Signup` -> `Add` -> `Post Processors` -> `JSON Extractor`
#   - Set `Name` to `JSON Extractor`.
#   - Check `Main sample and sub-samples`.
#   - Set `Names of created variables` to `EMAIL`.
#   - Set `JSON Path expressions` to `$.email`.
#   - Set `Default Values` to `Values_Not_Found`.
#
# -------------
# Login Request
# -------------
#
# - Right click `Load Test` -> `Add` -> `Sampler` -> `HTTP Request`
#   - Set `Name` to `Login`.
#   - Set `Protocol (http)` to `http`.
#   - Set `Server Name or IP` to `${SERVER}`.
#   - Set `Port Number` to `5000`.
#   - Choose `HTTP Request` to `POST`.
#   - Set `Path` to `/api/${API_VERSION}/login`.
#   - Check `Follow Redirects`.
#   - Check `Use Keepalive`.
#   - Click `Body Data` and enter (in the textbox below):
#
#     ```bash
#     { "email": "admin${USER}@ju.se", "password": "abc123" }
#     ```
#
# - Right click `Login` -> `Add` -> `Config Element` -> `HTTP Header Manager`
#   - Set `Name` to `HTTP Header Content Type`.
#   - Click the `Add` button.
#   - Set `Name` to `Content-Type` and `Value` to `application/json`.
#
# - Right click `Login` -> `Add` -> `Assertion` -> `Response Assertion`
#   - Set `Name` to `Response Assertion 200`.
#   - Check `Main sample only` under `Apply to`.
#   - Check `Response Code` under `Field to Test`.
#   - Check `Substring` under `Patterns to Test`.
#   - Click the `Add` button.
#   - Enter `200` in the textbox below `Patterns to Test`.
#
# - Right click `Login` -> `Add` -> `Assertion` -> `JSON Assertion`
#   - Set `Name` to `JSON Assertion Email Exists`.
#   - Set `Assert JSON Path exists` to `.email`.
#   - Check `Additionally assert value`.
#   - Set `Expected Value` to `"admin${USER}@ju.se"`.
#
# - Right click `Login` -> `Add` -> `Assertion` -> `JSON Assertion`
#   - Set `Name` to `JSON Assertion Token Exists`.
#   - Set `Assert JSON Path exists` to `.token`.
#
# - Right click `Login` -> `Add` -> `Post Processors` -> `Debug PostProcessor`
#   - Set `Name` to `Debug PostProcessor`.
#   - Set `JMeter properties` to `False`.
#   - Set `JMeter variables` to `True`.
#     - This will output our JMeter variables, e.g. the `EMAIL` varaible we extracted in the JSON Extractor under the `Signup` request.
#   - Set `Sampler properties` to `False`.
#   - Set `System properties` to `False`.
#
# ----------------
# PostTodo Request
# ----------------
#
# - Right click `Load Test` -> `Add` -> `Sampler` -> `HTTP Request`
#   - Set `Name` to `PostTodo`.
#   - Set `Protocol (http)` to `http`.
#   - Set `Server Name or IP` to `${SERVER}`.
#   - Set `Port Number` to `5000`.
#   - Choose `HTTP Request` to `POST`.
#   - Set `Path` to `/api/${API_VERSION}/todos`.
#   - Check `Follow Redirects`.
#   - Check `Use Keepalive`.
#   - Click `Body Data` and enter (in the textbox below):
#
#     ```bash
#     { "user_email": "admin${USER}@ju.se", "title": "pets", "progress": "79", "date": "2024-02-27T20:32:10.793Z" }
#     ```
#
# - Right click `PostTodo` -> `Add` -> `Config Element` -> `HTTP Header Manager`
#   - Set `Name` to `HTTP Header Content Type`.
#   - Click the `Add` button.
#   - Set `Name` to `Content-Type` and `Value` to `application/json`.
#
# - Right click `PostTodo` -> `Add` -> `Assertion` -> `Response Assertion`
#   - Set `Name` to `Response Assertion 200`.
#   - Check `Main sample only` under `Apply to`.
#   - Check `Response Code` under `Field to Test`.
#   - Check `Substring` under `Patterns to Test`.
#   - Click the `Add` button.
#   - Enter `200` in the textbox below `Patterns to Test`.
#
# - Right click `PostTodo` -> `Add` -> `Assertion` -> `Size Assertion`
#   - Set `Name` to `Size Assertion`.
#   - Check `Main sample only` under `Apply to`.
#   - Check `Full Response` under `Response Size Field to Test`.
#   - Under `Size to Assert`, set `Size in bytes` to `500` and check `<`.
#
# - Right click `PostTodo` -> `Add` -> `Assertion` -> `Duration Assertion`
#   - Set `Name` to `Duration Assertion`.
#   - Check `Main sample only` under `Apply to`.
#   - Set `Duration in milliseconds` to `1000` under `Duration to Assert`.
#
# - Right click `PostTodo` -> `Add` -> `Assertion` -> `JSON Assertion`
#   - Set `Name` to `JSON Assertion ID Exists`.
#   - Set `Assert JSON Path exists` to `.id`.
#
# - Right click `PostTodo` -> `Add` -> `Assertion` -> `JSON Assertion`
#   - Set `Name` to `JSON Assertion Progress Exists`.
#   - Set `Assert JSON Path exists` to `.progress`.
#   - Check `Additionally assert value`.
#   - Set `Expected Value` to `"79"`.
#
# - Right click `PostTodo` -> `Add` -> `Post Processors` -> `JSON Extractor`
#   - Set `Name` to `JSON Extractor`.
#   - Check `Main sample and sub-samples`.
#   - Set `Names of created variables` to `ID`.
#   - Set `JSON Path expressions` to `$.id`.
#   - Set `Default Values` to `Values_Not_Found`.
#
# ----------------
# GetTodos Request
# ----------------
#
# - Right click `Load Test` -> `Add` -> `Sampler` -> `HTTP Request`
#   - Set `Name` to `GetTodos`.
#   - Set `Protocol (http)` to `http`.
#   - Set `Server Name or IP` to `${SERVER}`.
#   - Set `Port Number` to `5000`.
#   - Choose `HTTP Request` to `GET`.
#   - Set `Path` to `/api/${API_VERSION}/todos/${EMAIL}`.
#     - `${EMAIL}` is the `EMAIL` variable's value that we extracted in the `Signup` requests JSON Extractor.
#   - Check `Follow Redirects`.
#   - Check `Use Keepalive`.
#
# - Right click `GetTodos` -> `Add` -> `Assertion` -> `Response Assertion`
#   - Set `Name` to `Response Assertion 200`.
#   - Check `Main sample only` under `Apply to`.
#   - Check `Response Code` under `Field to Test`.
#   - Check `Substring` under `Patterns to Test`.
#   - Click the `Add` button.
#   - Enter `200` in the textbox below `Patterns to Test`.
#
# - Right click `GetTodos` -> `Add` -> `Assertion` -> `JSON Assertion`
#   - Set `Name` to `JSON Assertion Progress Exists`.
#   - Set `Assert JSON Path exists` to `$.[0].progress`.
#   - Check `Additionally assert value`.
#   - Set `Expected Value` to `79`.
#
# ---------------
# PutTodo Request
# ---------------
#
# - Right click `Load Test` -> `Add` -> `Sampler` -> `HTTP Request`
#   - Set `Name` to `PutTodo`.
#   - Set `Protocol (http)` to `http`.
#   - Set `Server Name or IP` to `${SERVER}`.
#   - Set `Port Number` to `5000`.
#   - Choose `HTTP Request` to `PUT`.
#   - Set `Path` to `/api/${API_VERSION}/todos/${ID}`.
#     - `${ID}` is the value of the variable `ID` we extracted in the `PostTodo` request's JSON Extractor.
#   - Check `Follow Redirects`.
#   - Check `Use Keepalive`.
#   - Click `Body Data` and enter (in the textbox below):
#
#     ```bash
#     { "user_email": "admin${USER}@ju.se", "title": "pets", "progress": "99", "date": "2024-02-27T20:32:10.793Z" }
#     ```
#
# - Right click `PutTodo` -> `Add` -> `Config Element` -> `HTTP Header Manager`
#   - Set `Name` to `HTTP Header Content Type`.
#   - Click the `Add` button.
#   - Set `Name` to `Content-Type` and `Value` to `application/json`.
#
# - Right click `PutTodo` -> `Add` -> `Assertion` -> `Response Assertion`
#   - Set `Name` to `Response Assertion 200`.
#   - Check `Main sample only` under `Apply to`.
#   - Check `Response Code` under `Field to Test`.
#   - Check `Substring` under `Patterns to Test`.
#   - Click the `Add` button.
#   - Enter `200` in the textbox below `Patterns to Test`.
#
# - Right click `PutTodo` -> `Add` -> `Assertion` -> `JSON Assertion`
#   - Set `Name` to `JSON Assertion Progress Updated`.
#   - Set `Assert JSON Path exists` to `.progress`.
#   - Check `Additionally assert value`.
#   - Set `Expected Value` to `"99"`.
#
# ------------------
# DeleteTodo Request
# ------------------
#
# - Right click `Load Test` -> `Add` -> `Sampler` -> `HTTP Request`
#   - Set `Name` to `DeleteTodo`.
#   - Set `Protocol (http)` to `http`.
#   - Set `Server Name or IP` to `${SERVER}`.
#   - Set `Port Number` to `5000`.
#   - Choose `HTTP Request` to `DELETE`.
#   - Set `Path` to `/api/${API_VERSION}/todos/${ID}`.
#   - Check `Follow Redirects`.
#   - Check `Use Keepalive`.
#
# - Right click `DeleteTodo` -> `Add` -> `Assertion` -> `Response Assertion`
#   - Set `Name` to `Response Assertion 200`.
#   - Check `Main sample only` under `Apply to`.
#   - Check `Response Code` under `Field to Test`.
#   - Check `Substring` under `Patterns to Test`.
#   - Click the `Add` button.
#   - Enter `200` in the textbox below `Patterns to Test`.
#
# - Right click `PutTodo` -> `Add` -> `Assertion` -> `JSON Assertion`
#   - Set `Name` to `JSON Assertion ID Confirmation Exists`.
#   - Set `Assert JSON Path exists` to `.id`.
#   - Check `Additionally assert value`.
#   - Set `Expected Value` to `${ID}`.
#     - `${ID}` is the value of the variable `ID` we extracted in the `PostTodo` request's JSON Extractor.
#
# ---------
# Listeners
# ---------
#
# - Listeners are components that collect and display data from a test.
#   - Right click `TodoTestPlan` -> `Add` -> `Listener` -> `View Results Tree`
#   - Right click `TodoTestPlan` -> `Add` -> `Listener` -> `View Results in Table`
#   - Right click `TodoTestPlan` -> `Add` -> `Listener` -> `Graph Results`
#   - Right click `TodoTestPlan` -> `Add` -> `Listener` -> `Summary Report`
#   - Right click `TodoTestPlan` -> `Add` -> `Listener` -> `Simple Date Writer`
#     - Click the `Browse` button and choose to store the file `todoapp_log.csv` to some folder on your computer-
#     - Click the `Toggle` toolbar button to disable the listener (i.e. let's not include this listener in the test)-
#
# - Finally, click the `Save` tollbar button and save the Test Plan as `todoapp2.jmx` in the folder `02_JMeter`.

# %% [markdown]
# ## Bring up the Microservice Application

# %%
# !docker compose --project-name loadtesting -f docker-compose.yaml up -d --build --force-recreate
# Out:
# [+] Building 0.0s (0/1)                                          docker:default
# [+] Building 0.1s (10/10)                                        docker:default
#  => [server internal] load .dockerignore                                   0.0s
#  => => transferring context: 56B                                           0.0s
#  => [server internal] load build definition from Dockerfile                0.0s
#  => => transferring dockerfile: 154B                                       0.0s
#  => [server internal] load metadata for docker.io/library/node:20-alpine   0.0s
#  => [server 1/5] FROM docker.io/library/node:20-alpine                     0.0s
#  => [server internal] load build context                                   0.0s
#  => => transferring context: 157B                                          0.0s
#  => CACHED [server 2/5] WORKDIR /usr/src/app                               0.0s
#  => CACHED [server 3/5] COPY package*.json ./                              0.0s
#  => CACHED [server 4/5] RUN npm ci --omit=dev                              0.0s
#  => CACHED [server 5/5] COPY ./src ./src                                   0.0s
#  => [server] exporting to image                                            0.0s
#  => => exporting layers                                                    0.0s
#  => => writing image sha256:038de7e84669cc1380b25dc7c35d993ca483ebc4890b9  0.0s
#  => => naming to docker.io/library/loadtesting-server                      0.0s
# [+] Building 0.3s (18/18)                                        docker:default
#  => CACHED [client 2/6] WORKDIR /usr/src/app                               0.0s
#  => CACHED [server 3/5] COPY package*.json ./                              0.0s
#  => CACHED [server 4/5] RUN npm ci --omit=dev                              0.0s
#  => CACHED [server 5/5] COPY ./src ./src                                   0.0s
#  => [server] exporting to image                                            0.0s
#  => => exporting layers                                                    0.0s
#  => => writing image sha256:038de7e84669cc1380b25dc7c35d993ca483ebc4890b9  0.0s
#  => => naming to docker.io/library/loadtesting-server                      0.0s
#  => [client internal] load build definition from Dockerfile                0.0s
#  => => transferring dockerfile: 179B                                       0.0s
#  => [client internal] load .dockerignore                                   0.0s
#  => => transferring context: 56B                                           0.0s
#  => [client internal] load build context                                   0.0s
#  => => transferring context: 751B                                          0.0s
#  => CACHED [client 3/6] COPY package*.json ./                              0.0s
#  => CACHED [client 4/6] RUN npm ci --omit=dev                              0.0s
#  => CACHED [client 5/6] COPY ./src ./src                                   0.0s
#  => CACHED [client 6/6] COPY ./public ./public                             0.0s
#  => [client] exporting to image                                            0.0s
#  => => exporting layers                                                    0.0s
#  => => writing image sha256:b2e528ba70889723db9b83c246dd79a8666f122e1821b  0.0s
#  => => naming to docker.io/library/loadtesting-client                      0.0s
# [+] Building 0.3s (18/18) FINISHED                               docker:default
#  => [server internal] load .dockerignore                                   0.0s
#  => => transferring context: 56B                                           0.0s
#  => [server internal] load build definition from Dockerfile                0.0s
#  => => transferring dockerfile: 154B                                       0.0s
#  => [client internal] load metadata for docker.io/library/node:20-alpine   0.0s
#  => [client 1/6] FROM docker.io/library/node:20-alpine                     0.0s
#  => [server internal] load build context                                   0.0s
#  => => transferring context: 157B                                          0.0s
#  => CACHED [client 2/6] WORKDIR /usr/src/app                               0.0s
#  => CACHED [server 3/5] COPY package*.json ./                              0.0s
#  => CACHED [server 4/5] RUN npm ci --omit=dev                              0.0s
#  => CACHED [server 5/5] COPY ./src ./src                                   0.0s
#  => [server] exporting to image                                            0.0s
#  => => exporting layers                                                    0.0s
#  => => writing image sha256:038de7e84669cc1380b25dc7c35d993ca483ebc4890b9  0.0s
#  => => naming to docker.io/library/loadtesting-server                      0.0s
#  => [client internal] load build definition from Dockerfile                0.0s
#  => => transferring dockerfile: 179B                                       0.0s
#  => [client internal] load .dockerignore                                   0.0s
#  => => transferring context: 56B                                           0.0s
#  => [client internal] load build context                                   0.0s
#  => => transferring context: 751B                                          0.0s
#  => CACHED [client 3/6] COPY package*.json ./                              0.0s
#  => CACHED [client 4/6] RUN npm ci --omit=dev                              0.0s
#  => CACHED [client 5/6] COPY ./src ./src                                   0.0s
#  => CACHED [client 6/6] COPY ./public ./public                             0.0s
#  => [client] exporting to image                                            0.0s
#  => => exporting layers                                                    0.0s
#  => => writing image sha256:b2e528ba70889723db9b83c246dd79a8666f122e1821b  0.0s
#  => => naming to docker.io/library/loadtesting-client                      0.0s
# [+] Running 0/0
#  ⠋ Network loadtesting_loadtesting  C...                                   0.0s
# [+] Running 3/1
#  ✔ Network loadtesting_loadtesting  C...                                   0.0s
#  ✔ Container adminer                Created                                0.1s
#  ✔ Container postgres               Created                                0.1s
#  ⠋ Container server                 Creating                               0.0s
# [+] Running 5/4
#  ✔ Network loadtesting_loadtesting  C...                                   0.0s
#  ✔ Container adminer                Created                                0.1s
#  ✔ Container postgres               Created                                0.1s
#  ✔ Container server                 Created                                0.1s
#  ✔ Container client                 Created                                0.0s
# [+] Running 5/5
#  ✔ Network loadtesting_loadtesting  C...                                   0.0s
#  ✔ Container adminer                Created                                0.1s
#  ✔ Container postgres               Created                                0.1s
#  ✔ Container server                 Created                                0.1s
#  ✔ Container client                 Created                                0.0s
# [+] Running 5/5
#  ✔ Network loadtesting_loadtesting  C...                                   0.0s
#  ✔ Container adminer                Created                                0.1s
#  ✔ Container postgres               Created                                0.1s
#  ✔ Container server                 Created                                0.1s
#  ✔ Container client                 Created                                0.0s
# [+] Running 5/5
#  ✔ Network loadtesting_loadtesting  C...                                   0.0s
#  ✔ Container adminer                Created                                0.1s
#  ✔ Container postgres               Created                                0.1s
#  ✔ Container server                 Created                                0.1s
#  ✔ Container client                 Created                                0.0s
# [+] Running 5/5
#  ✔ Network loadtesting_loadtesting  C...                                   0.0s
#  ✔ Container adminer                Created                                0.1s
#  ✔ Container postgres               Created                                0.1s
#  ✔ Container server                 Created                                0.1s
#  ✔ Container client                 Created                                0.0s
# [+] Running 5/5
#  ✔ Network loadtesting_loadtesting  C...                                   0.0s
#  ✔ Container adminer                Started                                0.1s
#  ✔ Container postgres               Created                                0.1s
#  ✔ Container server                 Created                                0.1s
#  ✔ Container client                 Created                                0.0s
# [+] Running 5/5
#  ✔ Network loadtesting_loadtesting  C...                                   0.0s
#  ✔ Container adminer                Started                                0.1s
#  ✔ Container postgres               Created                                0.1s
#  ✔ Container server                 Created                                0.1s
#  ✔ Container client                 Created                                0.0s
# [+] Running 5/5
#  ✔ Network loadtesting_loadtesting  C...                                   0.0s
#  ✔ Container adminer                Started                                0.1s
#  ✔ Container postgres               Started                                0.1s
#  ✔ Container server                 Created                                0.1s
#  ✔ Container client                 Created                                0.0s
# [+] Running 5/5
#  ✔ Network loadtesting_loadtesting  C...                                   0.0s
#  ✔ Container adminer                Started                                0.1s
#  ✔ Container postgres               Started                                0.1s
#  ✔ Container server                 Created                                0.1s
#  ✔ Container client                 Created                                0.0s
# [+] Running 5/5
#  ✔ Network loadtesting_loadtesting  C...                                   0.0s
#  ✔ Container adminer                Started                                0.1s
#  ✔ Container postgres               Started                                0.1s
#  ✔ Container server                 Created                                0.1s
#  ✔ Container client                 Created                                0.0s
# [+] Running 5/5
#  ✔ Network loadtesting_loadtesting  C...                                   0.0s
#  ✔ Container adminer                Started                                0.1s
#  ✔ Container postgres               Started                                0.1s
#  ✔ Container server                 Created                                0.1s
#  ✔ Container client                 Created                                0.0s
# [+] Running 5/5
#  ✔ Network loadtesting_loadtesting  C...                                   0.0s
#  ✔ Container adminer                Started                                0.1s
#  ✔ Container postgres               Started                                0.1s
#  ✔ Container server                 Started                                0.1s
#  ✔ Container client                 Created                                0.0s
# [+] Running 5/5
#  ✔ Network loadtesting_loadtesting  C...                                   0.0s
#  ✔ Container adminer                Started                                0.1s
#  ✔ Container postgres               Started                                0.1s
#  ✔ Container server                 Started                                0.1s
#  ✔ Container client                 Created                                0.0s
# [+] Running 5/5
#  ✔ Network loadtesting_loadtesting  C...                                   0.0s
#  ✔ Container adminer                Started                                0.1s
#  ✔ Container postgres               Started                                0.1s
#  ✔ Container server                 Started                                0.1s
#  ✔ Container client                 Created                                0.0s
# [+] Running 5/5
#  ✔ Network loadtesting_loadtesting  C...                                   0.0s
#  ✔ Container adminer                Started                                0.1s
#  ✔ Container postgres               Started                                0.1s
#  ✔ Container server                 Started                                0.1s
#  ✔ Container client                 Created                                0.0s
# [+] Running 5/5
#  ✔ Network loadtesting_loadtesting  C...                                   0.0s
#  ✔ Container adminer                Started                                0.1s
#  ✔ Container postgres               Started                                0.1s
#  ✔ Container server                 Started                                0.1s
#  ✔ Container client                 Started                                0.0s

# %% [markdown]
# ## Run Loadtest for the Microservice Application
#
# <img src="../notebook_images/jmeter_open.png" width="400" height="400" style="margin: 0 2em;float:right" />
#
# - Click the `Open` toolbar button in the JMeter GUI.
# - Select the file: `07_Loadtesting/02_JMeter/todoapp.jmx`.
# - CLick the `Run` button.

# %% [markdown]
# ## Tear Down and Bring Up the Microservices Application

# %%
#!docker compose --project-name loadtesting -f docker-compose.yaml down --rmi all
# !docker compose --project-name loadtesting -f docker-compose.yaml down --rmi local
# !docker compose --project-name loadtesting -f docker-compose.yaml up -d --build --force-recreate
# Out:
# [+] Running 0/0
#  ⠋ Container adminer  Stopping                                             0.1s
#  ⠋ Container client   Stopping                                             0.1s
# [+] Running 0/2
#  ⠙ Container adminer  Stopping                                             0.2s
#  ⠙ Container client   Stopping                                             0.2s
# [+] Running 0/2
#  ⠹ Container adminer  Stopping                                             0.3s
#  ⠹ Container client   Stopping                                             0.3s
# [+] Running 0/2
#  ⠸ Container adminer  Stopping                                             0.4s
#  ⠸ Container client   Stopping                                             0.4s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠼ Container client   Stopping                                             0.5s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠴ Container client   Stopping                                             0.6s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠦ Container client   Stopping                                             0.7s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠧ Container client   Stopping                                             0.8s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠇ Container client   Stopping                                             0.9s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠏ Container client   Stopping                                             1.0s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠋ Container client   Stopping                                             1.1s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠙ Container client   Stopping                                             1.2s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠹ Container client   Stopping                                             1.3s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠸ Container client   Stopping                                             1.4s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠼ Container client   Stopping                                             1.5s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠴ Container client   Stopping                                             1.6s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠦ Container client   Stopping                                             1.7s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠧ Container client   Stopping                                             1.8s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠇ Container client   Stopping                                             1.9s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠏ Container client   Stopping                                             2.0s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠋ Container client   Stopping                                             2.1s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠙ Container client   Stopping                                             2.2s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠹ Container client   Stopping                                             2.3s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠸ Container client   Stopping                                             2.4s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠼ Container client   Stopping                                             2.5s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠴ Container client   Stopping                                             2.6s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠦ Container client   Stopping                                             2.7s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠧ Container client   Stopping                                             2.8s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠇ Container client   Stopping                                             2.9s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠏ Container client   Stopping                                             3.0s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠋ Container client   Stopping                                             3.1s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠙ Container client   Stopping                                             3.2s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠹ Container client   Stopping                                             3.3s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠸ Container client   Stopping                                             3.4s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠼ Container client   Stopping                                             3.5s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠴ Container client   Stopping                                             3.6s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠦ Container client   Stopping                                             3.7s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠧ Container client   Stopping                                             3.8s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠇ Container client   Stopping                                             3.9s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠏ Container client   Stopping                                             4.0s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠋ Container client   Stopping                                             4.1s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠙ Container client   Stopping                                             4.2s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠹ Container client   Stopping                                             4.3s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠸ Container client   Stopping                                             4.4s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠼ Container client   Stopping                                             4.5s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠴ Container client   Stopping                                             4.6s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠦ Container client   Stopping                                             4.7s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠧ Container client   Stopping                                             4.8s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠇ Container client   Stopping                                             4.9s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠏ Container client   Stopping                                             5.0s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠋ Container client   Stopping                                             5.1s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠙ Container client   Stopping                                             5.2s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠹ Container client   Stopping                                             5.3s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠸ Container client   Stopping                                             5.4s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠼ Container client   Stopping                                             5.5s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠴ Container client   Stopping                                             5.6s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠦ Container client   Stopping                                             5.7s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠧ Container client   Stopping                                             5.8s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠇ Container client   Stopping                                             5.9s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠏ Container client   Stopping                                             6.0s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠋ Container client   Stopping                                             6.1s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠙ Container client   Stopping                                             6.2s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠹ Container client   Stopping                                             6.3s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠸ Container client   Stopping                                             6.4s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠼ Container client   Stopping                                             6.5s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠴ Container client   Stopping                                             6.6s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠦ Container client   Stopping                                             6.7s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠧ Container client   Stopping                                             6.8s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠇ Container client   Stopping                                             6.9s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠏ Container client   Stopping                                             7.0s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠋ Container client   Stopping                                             7.1s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠙ Container client   Stopping                                             7.2s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠹ Container client   Stopping                                             7.3s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠸ Container client   Stopping                                             7.4s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠼ Container client   Stopping                                             7.5s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠴ Container client   Stopping                                             7.6s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠦ Container client   Stopping                                             7.7s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠧ Container client   Stopping                                             7.8s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠇ Container client   Stopping                                             7.9s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠏ Container client   Stopping                                             8.0s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠋ Container client   Stopping                                             8.1s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠙ Container client   Stopping                                             8.2s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠹ Container client   Stopping                                             8.3s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠸ Container client   Stopping                                             8.4s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠼ Container client   Stopping                                             8.5s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠴ Container client   Stopping                                             8.6s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠦ Container client   Stopping                                             8.7s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠧ Container client   Stopping                                             8.8s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠇ Container client   Stopping                                             8.9s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠏ Container client   Stopping                                             9.0s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠋ Container client   Stopping                                             9.1s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠙ Container client   Stopping                                             9.2s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠹ Container client   Stopping                                             9.3s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠸ Container client   Stopping                                             9.4s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠼ Container client   Stopping                                             9.5s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠴ Container client   Stopping                                             9.6s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠦ Container client   Stopping                                             9.7s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠧ Container client   Stopping                                             9.8s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠇ Container client   Stopping                                             9.9s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠏ Container client   Stopping                                            10.0s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠋ Container client   Stopping                                            10.1s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠙ Container client   Stopping                                            10.2s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠹ Container client   Stopping                                            10.3s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠸ Container client   Stopping                                            10.4s
# [+] Running 1/2
#  ✔ Container adminer  Removed                                              0.4s
#  ⠼ Container client   Stopping                                            10.5s
# [+] Running 2/2
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠋ Container server   Stopping                                             0.0s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠙ Container server   Stopping                                             0.1s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠹ Container server   Stopping                                             0.2s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠸ Container server   Stopping                                             0.3s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠼ Container server   Stopping                                             0.4s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠴ Container server   Stopping                                             0.5s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠦ Container server   Stopping                                             0.6s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠧ Container server   Stopping                                             0.7s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠇ Container server   Stopping                                             0.8s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠏ Container server   Stopping                                             0.9s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠋ Container server   Stopping                                             1.0s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠙ Container server   Stopping                                             1.1s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠹ Container server   Stopping                                             1.2s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠸ Container server   Stopping                                             1.3s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠼ Container server   Stopping                                             1.4s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠴ Container server   Stopping                                             1.5s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠦ Container server   Stopping                                             1.6s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠧ Container server   Stopping                                             1.7s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠇ Container server   Stopping                                             1.8s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠏ Container server   Stopping                                             1.9s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠋ Container server   Stopping                                             2.0s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠙ Container server   Stopping                                             2.1s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠹ Container server   Stopping                                             2.2s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠸ Container server   Stopping                                             2.3s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠼ Container server   Stopping                                             2.4s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠴ Container server   Stopping                                             2.5s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠦ Container server   Stopping                                             2.6s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠧ Container server   Stopping                                             2.7s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠇ Container server   Stopping                                             2.8s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠏ Container server   Stopping                                             2.9s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠋ Container server   Stopping                                             3.0s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠙ Container server   Stopping                                             3.1s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠹ Container server   Stopping                                             3.2s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠸ Container server   Stopping                                             3.3s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠼ Container server   Stopping                                             3.4s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠴ Container server   Stopping                                             3.5s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠦ Container server   Stopping                                             3.6s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠧ Container server   Stopping                                             3.7s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠇ Container server   Stopping                                             3.8s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠏ Container server   Stopping                                             3.9s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠋ Container server   Stopping                                             4.0s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠙ Container server   Stopping                                             4.1s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠹ Container server   Stopping                                             4.2s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠸ Container server   Stopping                                             4.3s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠼ Container server   Stopping                                             4.4s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠴ Container server   Stopping                                             4.5s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠦ Container server   Stopping                                             4.6s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠧ Container server   Stopping                                             4.7s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠇ Container server   Stopping                                             4.8s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠏ Container server   Stopping                                             4.9s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠋ Container server   Stopping                                             5.0s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠙ Container server   Stopping                                             5.1s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠹ Container server   Stopping                                             5.2s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠸ Container server   Stopping                                             5.3s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠼ Container server   Stopping                                             5.4s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠴ Container server   Stopping                                             5.5s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠦ Container server   Stopping                                             5.6s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠧ Container server   Stopping                                             5.7s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠇ Container server   Stopping                                             5.8s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠏ Container server   Stopping                                             5.9s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠋ Container server   Stopping                                             6.0s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠙ Container server   Stopping                                             6.1s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠹ Container server   Stopping                                             6.2s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠸ Container server   Stopping                                             6.3s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠼ Container server   Stopping                                             6.4s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠴ Container server   Stopping                                             6.5s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠦ Container server   Stopping                                             6.6s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠧ Container server   Stopping                                             6.7s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠇ Container server   Stopping                                             6.8s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠏ Container server   Stopping                                             6.9s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠋ Container server   Stopping                                             7.0s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠙ Container server   Stopping                                             7.1s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠹ Container server   Stopping                                             7.2s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠸ Container server   Stopping                                             7.3s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠼ Container server   Stopping                                             7.4s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠴ Container server   Stopping                                             7.5s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠦ Container server   Stopping                                             7.6s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠧ Container server   Stopping                                             7.7s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠇ Container server   Stopping                                             7.8s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠏ Container server   Stopping                                             7.9s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠋ Container server   Stopping                                             8.0s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠙ Container server   Stopping                                             8.1s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠹ Container server   Stopping                                             8.2s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠸ Container server   Stopping                                             8.3s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠼ Container server   Stopping                                             8.4s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠴ Container server   Stopping                                             8.5s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠦ Container server   Stopping                                             8.6s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠧ Container server   Stopping                                             8.7s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠇ Container server   Stopping                                             8.8s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠏ Container server   Stopping                                             8.9s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠋ Container server   Stopping                                             9.0s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠙ Container server   Stopping                                             9.1s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠹ Container server   Stopping                                             9.2s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠸ Container server   Stopping                                             9.3s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠼ Container server   Stopping                                             9.4s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠴ Container server   Stopping                                             9.5s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠦ Container server   Stopping                                             9.6s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠧ Container server   Stopping                                             9.7s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠇ Container server   Stopping                                             9.8s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠏ Container server   Stopping                                             9.9s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠋ Container server   Stopping                                            10.0s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠙ Container server   Stopping                                            10.1s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠹ Container server   Stopping                                            10.2s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠸ Container server   Stopping                                            10.3s
# [+] Running 2/3
#  ✔ Container adminer  Removed                                              0.4s
#  ✔ Container client   Removed                                             10.5s
#  ⠼ Container server   Stopping                                            10.4s
# [+] Running 3/3
#  ✔ Container adminer   Removed                                             0.4s
#  ✔ Container client    Removed                                            10.5s
#  ✔ Container server    Removed                                            10.5s
#  ⠋ Container postgres  Stopping                                            0.1s
# [+] Running 3/4
#  ✔ Container adminer   Removed                                             0.4s
#  ✔ Container client    Removed                                            10.5s
#  ✔ Container server    Removed                                            10.5s
#  ⠙ Container postgres  Stopping                                            0.2s
# [+] Running 3/4
#  ✔ Container adminer   Removed                                             0.4s
#  ✔ Container client    Removed                                            10.5s
#  ✔ Container server    Removed                                            10.5s
#  ⠹ Container postgres  Stopping                                            0.3s
# [+] Running 3/4
#  ✔ Container adminer   Removed                                             0.4s
#  ✔ Container client    Removed                                            10.5s
#  ✔ Container server    Removed                                            10.5s
#  ⠸ Container postgres  Stopping                                            0.4s
# [+] Running 3/4
#  ✔ Container adminer   Removed                                             0.4s
#  ✔ Container client    Removed                                            10.5s
#  ✔ Container server    Removed                                            10.5s
#  ⠼ Container postgres  Stopping                                            0.5s
# [+] Running 6/4
#  ✔ Container adminer                Removed                                0.4s
#  ✔ Container client                 Removed                               10.5s
#  ✔ Container server                 Removed                               10.5s
#  ✔ Container postgres               Removed                                0.5s
#  ✔ Image loadtesting-server:latest  R...                                   0.0s
#  ✔ Image loadtesting-client:latest  R...                                   0.0s
#  ⠋ Network loadtesting_loadtesting  R...                                   0.0s
# [+] Running 6/7
#  ✔ Container adminer                Removed                                0.4s
#  ✔ Container client                 Removed                               10.5s
#  ✔ Container server                 Removed                               10.5s
#  ✔ Container postgres               Removed                                0.5s
#  ✔ Image loadtesting-server:latest  R...                                   0.0s
#  ✔ Image loadtesting-client:latest  R...                                   0.0s
#  ⠙ Network loadtesting_loadtesting  R...                                   0.1s
# [+] Running 6/7
#  ✔ Container adminer                Removed                                0.4s
#  ✔ Container client                 Removed                               10.5s
#  ✔ Container server                 Removed                               10.5s
#  ✔ Container postgres               Removed                                0.5s
#  ✔ Image loadtesting-server:latest  R...                                   0.0s
#  ✔ Image loadtesting-client:latest  R...                                   0.0s
#  ⠹ Network loadtesting_loadtesting  R...                                   0.2s
# [+] Running 7/7
#  ✔ Container adminer                Removed                                0.4s
#  ✔ Container client                 Removed                               10.5s
#  ✔ Container server                 Removed                               10.5s
#  ✔ Container postgres               Removed                                0.5s
#  ✔ Image loadtesting-server:latest  R...                                   0.0s
#  ✔ Image loadtesting-client:latest  R...                                   0.0s
#  ✔ Network loadtesting_loadtesting  R...                                   0.3s
# [+] Building 0.0s (0/2)                                          docker:default
# [+] Building 0.2s (10/10)                                        docker:default
#  => [server internal] load .dockerignore                                   0.0s
#  => => transferring context: 56B                                           0.0s
#  => [server internal] load build definition from Dockerfile                0.0s
#  => => transferring dockerfile: 154B                                       0.0s
#  => [server internal] load metadata for docker.io/library/node:20-alpine   0.0s
#  => [server 1/5] FROM docker.io/library/node:20-alpine                     0.0s
#  => [server internal] load build context                                   0.0s
#  => => transferring context: 157B                                          0.0s
#  => CACHED [server 2/5] WORKDIR /usr/src/app                               0.0s
#  => CACHED [server 3/5] COPY package*.json ./                              0.0s
#  => CACHED [server 4/5] RUN npm ci --omit=dev                              0.0s
#  => CACHED [server 5/5] COPY ./src ./src                                   0.0s
#  => [server] exporting to image                                            0.0s
#  => => exporting layers                                                    0.0s
#  => => writing image sha256:038de7e84669cc1380b25dc7c35d993ca483ebc4890b9  0.0s
#  => => naming to docker.io/library/loadtesting-server                      0.0s
# [+] Building 0.3s (11/12)                                        docker:default
#  => [server internal] load .dockerignore                                   0.0s
#  => => transferring context: 56B                                           0.0s
#  => [server internal] load build definition from Dockerfile                0.0s
#  => => transferring dockerfile: 154B                                       0.0s
#  => [client internal] load metadata for docker.io/library/node:20-alpine   0.0s
#  => [server 1/5] FROM docker.io/library/node:20-alpine                     0.0s
#  => [server internal] load build context                                   0.0s
#  => => transferring context: 157B                                          0.0s
#  => CACHED [server 2/5] WORKDIR /usr/src/app                               0.0s
#  => CACHED [server 3/5] COPY package*.json ./                              0.0s
#  => CACHED [server 4/5] RUN npm ci --omit=dev                              0.0s
#  => CACHED [server 5/5] COPY ./src ./src                                   0.0s
#  => [server] exporting to image                                            0.0s
#  => => exporting layers                                                    0.0s
#  => => writing image sha256:038de7e84669cc1380b25dc7c35d993ca483ebc4890b9  0.0s
#  => => naming to docker.io/library/loadtesting-server                      0.0s
#  => [client internal] load .dockerignore                                   0.0s
#  => => transferring context: 56B                                           0.0s
#  => [client internal] load build definition from Dockerfile                0.0s
#  => => transferring dockerfile: 179B                                       0.0s
# [+] Building 0.4s (18/18) FINISHED                               docker:default
#  => [server internal] load .dockerignore                                   0.0s
#  => => transferring context: 56B                                           0.0s
#  => [server internal] load build definition from Dockerfile                0.0s
#  => => transferring dockerfile: 154B                                       0.0s
#  => [client internal] load metadata for docker.io/library/node:20-alpine   0.0s
#  => [client 1/6] FROM docker.io/library/node:20-alpine                     0.0s
#  => [server internal] load build context                                   0.0s
#  => => transferring context: 157B                                          0.0s
#  => CACHED [client 2/6] WORKDIR /usr/src/app                               0.0s
#  => CACHED [server 3/5] COPY package*.json ./                              0.0s
#  => CACHED [server 4/5] RUN npm ci --omit=dev                              0.0s
#  => CACHED [server 5/5] COPY ./src ./src                                   0.0s
#  => [server] exporting to image                                            0.0s
#  => => exporting layers                                                    0.0s
#  => => writing image sha256:038de7e84669cc1380b25dc7c35d993ca483ebc4890b9  0.0s
#  => => naming to docker.io/library/loadtesting-server                      0.0s
#  => [client internal] load .dockerignore                                   0.0s
#  => => transferring context: 56B                                           0.0s
#  => [client internal] load build definition from Dockerfile                0.0s
#  => => transferring dockerfile: 179B                                       0.0s
#  => [client internal] load build context                                   0.0s
#  => => transferring context: 751B                                          0.0s
#  => CACHED [client 3/6] COPY package*.json ./                              0.0s
#  => CACHED [client 4/6] RUN npm ci --omit=dev                              0.0s
#  => CACHED [client 5/6] COPY ./src ./src                                   0.0s
#  => CACHED [client 6/6] COPY ./public ./public                             0.0s
#  => [client] exporting to image                                            0.0s
#  => => exporting layers                                                    0.0s
#  => => writing image sha256:b2e528ba70889723db9b83c246dd79a8666f122e1821b  0.0s
#  => => naming to docker.io/library/loadtesting-client                      0.0s
# [+] Running 1/0
#  ✔ Network loadtesting_loadtesting  C...                                   0.0s
#  ⠋ Container postgres               Creating                               0.0s
#  ⠋ Container adminer                Creating                               0.0s
# [+] Running 4/3
#  ✔ Network loadtesting_loadtesting  C...                                   0.0s
#  ✔ Container postgres               Created                                0.1s
#  ✔ Container adminer                Created                                0.1s
#  ✔ Container server                 Created                                0.0s
#  ⠋ Container client                 Creating                               0.0s
# [+] Running 5/5
#  ✔ Network loadtesting_loadtesting  C...                                   0.0s
#  ✔ Container postgres               Created                                0.1s
#  ✔ Container adminer                Created                                0.1s
#  ✔ Container server                 Created                                0.0s
#  ✔ Container client                 Created                                0.0s
# [+] Running 5/5
#  ✔ Network loadtesting_loadtesting  C...                                   0.0s
#  ✔ Container postgres               Created                                0.1s
#  ✔ Container adminer                Created                                0.1s
#  ✔ Container server                 Created                                0.0s
#  ✔ Container client                 Created                                0.0s
# [+] Running 5/5
#  ✔ Network loadtesting_loadtesting  C...                                   0.0s
#  ✔ Container postgres               Created                                0.1s
#  ✔ Container adminer                Created                                0.1s
#  ✔ Container server                 Created                                0.0s
#  ✔ Container client                 Created                                0.0s
# [+] Running 5/5
#  ✔ Network loadtesting_loadtesting  C...                                   0.0s
#  ✔ Container postgres               Created                                0.1s
#  ✔ Container adminer                Created                                0.1s
#  ✔ Container server                 Created                                0.0s
#  ✔ Container client                 Created                                0.0s
# [+] Running 5/5
#  ✔ Network loadtesting_loadtesting  C...                                   0.0s
#  ✔ Container postgres               Started                                0.1s
#  ✔ Container adminer                Created                                0.1s
#  ✔ Container server                 Created                                0.0s
#  ✔ Container client                 Created                                0.0s
# [+] Running 5/5
#  ✔ Network loadtesting_loadtesting  C...                                   0.0s
#  ✔ Container postgres               Started                                0.1s
#  ✔ Container adminer                Created                                0.1s
#  ✔ Container server                 Created                                0.0s
#  ✔ Container client                 Created                                0.0s
# [+] Running 5/5
#  ✔ Network loadtesting_loadtesting  C...                                   0.0s
#  ✔ Container postgres               Started                                0.1s
#  ✔ Container adminer                Started                                0.1s
#  ✔ Container server                 Created                                0.0s
#  ✔ Container client                 Created                                0.0s
# [+] Running 5/5
#  ✔ Network loadtesting_loadtesting  C...                                   0.0s
#  ✔ Container postgres               Started                                0.1s
#  ✔ Container adminer                Started                                0.1s
#  ✔ Container server                 Created                                0.0s
#  ✔ Container client                 Created                                0.0s
# [+] Running 5/5
#  ✔ Network loadtesting_loadtesting  C...                                   0.0s
#  ✔ Container postgres               Started                                0.1s
#  ✔ Container adminer                Started                                0.1s
#  ✔ Container server                 Created                                0.0s
#  ✔ Container client                 Created                                0.0s
# [+] Running 5/5
#  ✔ Network loadtesting_loadtesting  C...                                   0.0s
#  ✔ Container postgres               Started                                0.1s
#  ✔ Container adminer                Started                                0.1s
#  ✔ Container server                 Started                                0.0s
#  ✔ Container client                 Created                                0.0s
# [+] Running 5/5
#  ✔ Network loadtesting_loadtesting  C...                                   0.0s
#  ✔ Container postgres               Started                                0.1s
#  ✔ Container adminer                Started                                0.1s
#  ✔ Container server                 Started                                0.0s
#  ✔ Container client                 Created                                0.0s
# [+] Running 5/5
#  ✔ Network loadtesting_loadtesting  C...                                   0.0s
#  ✔ Container postgres               Started                                0.1s
#  ✔ Container adminer                Started                                0.1s
#  ✔ Container server                 Started                                0.0s
#  ✔ Container client                 Created                                0.0s
# [+] Running 5/5
#  ✔ Network loadtesting_loadtesting  C...                                   0.0s
#  ✔ Container postgres               Started                                0.1s
#  ✔ Container adminer                Started                                0.1s
#  ✔ Container server                 Started                                0.0s
#  ✔ Container client                 Created                                0.0s
# [+] Running 5/5
#  ✔ Network loadtesting_loadtesting  C...                                   0.0s
#  ✔ Container postgres               Started                                0.1s
#  ✔ Container adminer                Started                                0.1s
#  ✔ Container server                 Started                                0.0s
#  ✔ Container client                 Started                                0.0s

# %% [markdown]
# ## Let's Run the Same Test Using the JMeter CLI
#
# - Notice that we see the number of `active`, `started` and `finished` threads.

# %%
# !apache-jmeter-5.6.3/bin/jmeter -n -t todoapp.jmx -l todoapp.csv -e -o todoapp_report
# Out:
# WARN StatusConsoleListener The use of package scanning to locate plugins is deprecated and will be removed in a future release
# WARN StatusConsoleListener The use of package scanning to locate plugins is deprecated and will be removed in a future release
# WARN StatusConsoleListener The use of package scanning to locate plugins is deprecated and will be removed in a future release
# WARN StatusConsoleListener The use of package scanning to locate plugins is deprecated and will be removed in a future release
# Creating summariser <summary>
# Created the tree successfully using todoapp.jmx
# Starting standalone test @ 2024 Mar 4 12:04:20 CET (1709550260965)
# Waiting for possible Shutdown/StopTestNow/HeapDump/ThreadDump message on port 4445
# Warning: Nashorn engine is planned to be removed from a future JDK release
# summary +    603 in 00:00:09 =   69.6/s Avg:   396 Min:     3 Max:  1526 Err:   102 (16.92%) Active: 50 Started: 50 Finished: 0
# summary +   3299 in 00:00:30 =  109.5/s Avg:   458 Min:    31 Max:  1170 Err:   558 (16.91%) Active: 50 Started: 50 Finished: 0
# summary =   3902 in 00:00:39 =  100.6/s Avg:   448 Min:     3 Max:  1526 Err:   660 (16.91%)
# summary +   2527 in 00:00:23 =  111.3/s Avg:   450 Min:    22 Max:  1235 Err:   410 (16.22%) Active: 0 Started: 50 Finished: 50
# summary =   6429 in 00:01:01 =  104.5/s Avg:   449 Min:     3 Max:  1526 Err:  1070 (16.64%)
# Tidying up ...    @ 2024 Mar 4 12:05:22 CET (1709550322835)
# ... end of run

# %% [markdown]
# ## Let's look at the Test Results
#
# The following is the output from the test:
# - The file `jmeter.log` contains the logs for the test.
# - The file `todoapp.csv` contains the test results in a `Comma Separated Values` format
#   - This file can be loaded in an external tool for further analysis.
# - The folder `todoapp_report` contains a static website with information about the test.
#
# Let's open the file `index.html` in the folder `todoapp_report` and look at the web-based report:
# - The "Dashboard" contains an overview of the test results:
#   - APDEX (Application Performandce Index)
#     - https://en.wikipedia.org/wiki/Apdex
#     - https://www.apdex.org/
#   - Requests Summary
#     -  Number of failed/passed requests
#   - Statistics
#     - Number of executions per request
#     - Response times per request
#     - Throughput per request
#     - Network (KB/s) per request
#   - Errors
#     - Type of error
#     - Numer of errors
#     - % in errors
#     - % in all samples
#   - Top 5 Errors per Samples (e.g. per request type)
# - The "Charts" contains various charts for:
#   - Over Time
#     - Response Times Over Time
#     - Response Time Percentiles Over Time (successful responses)
#     - Active Threads Over Time
#     - Bytes Throughput Over Time
#     - Latencies Over Time
#     - Connect Time Over Time
#   - Throughput
#     - Hits Per Second
#     - Codes Per Second
#     - Transactions Per Second
#     - Total Transactions Per Second
#     - Response Time Vs Request
#     - Latency Vs Request
#   - Response Times
#     - Response Time Percentiles
#     - Response Time Overview
#     - Time Vs Threads
#     - Response Time Distribution

# %%
# !firefox todoapp_report/index.html
# Out:
# [GFX1-]: glxtest: ManageChildProcess failed

# %% [markdown]
# ## Tear Down the Microservices Application

# %%
#!docker compose --project-name loadtesting -f docker-compose.yaml down --rmi all
# !docker compose --project-name loadtesting -f docker-compose.yaml down --rmi local
# Out:
# [+] Running 0/0
#  ⠋ Container client   Stopping                                             0.1s
#  ⠋ Container adminer  Stopping                                             0.1s
# [+] Running 0/2
#  ⠙ Container client   Stopping                                             0.2s
#  ⠙ Container adminer  Stopping                                             0.2s
# [+] Running 0/2
#  ⠹ Container client   Stopping                                             0.3s
#  ⠹ Container adminer  Stopping                                             0.3s
# [+] Running 0/2
#  ⠸ Container client   Stopping                                             0.4s
#  ⠸ Container adminer  Stopping                                             0.4s
# [+] Running 1/2
#  ⠼ Container client   Stopping                                             0.5s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠴ Container client   Stopping                                             0.6s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠦ Container client   Stopping                                             0.7s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠧ Container client   Stopping                                             0.8s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠇ Container client   Stopping                                             0.9s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠏ Container client   Stopping                                             1.0s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠋ Container client   Stopping                                             1.1s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠙ Container client   Stopping                                             1.2s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠹ Container client   Stopping                                             1.3s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠸ Container client   Stopping                                             1.4s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠼ Container client   Stopping                                             1.5s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠴ Container client   Stopping                                             1.6s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠦ Container client   Stopping                                             1.7s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠧ Container client   Stopping                                             1.8s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠇ Container client   Stopping                                             1.9s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠏ Container client   Stopping                                             2.0s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠋ Container client   Stopping                                             2.1s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠙ Container client   Stopping                                             2.2s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠹ Container client   Stopping                                             2.3s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠸ Container client   Stopping                                             2.4s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠼ Container client   Stopping                                             2.5s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠴ Container client   Stopping                                             2.6s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠦ Container client   Stopping                                             2.7s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠧ Container client   Stopping                                             2.8s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠇ Container client   Stopping                                             2.9s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠏ Container client   Stopping                                             3.0s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠋ Container client   Stopping                                             3.1s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠙ Container client   Stopping                                             3.2s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠹ Container client   Stopping                                             3.3s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠸ Container client   Stopping                                             3.4s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠼ Container client   Stopping                                             3.5s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠴ Container client   Stopping                                             3.6s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠦ Container client   Stopping                                             3.7s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠧ Container client   Stopping                                             3.8s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠇ Container client   Stopping                                             3.9s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠏ Container client   Stopping                                             4.0s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠋ Container client   Stopping                                             4.1s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠙ Container client   Stopping                                             4.2s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠹ Container client   Stopping                                             4.3s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠸ Container client   Stopping                                             4.4s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠼ Container client   Stopping                                             4.5s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠴ Container client   Stopping                                             4.6s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠦ Container client   Stopping                                             4.7s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠧ Container client   Stopping                                             4.8s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠇ Container client   Stopping                                             4.9s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠏ Container client   Stopping                                             5.0s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠋ Container client   Stopping                                             5.1s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠙ Container client   Stopping                                             5.2s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠹ Container client   Stopping                                             5.3s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠸ Container client   Stopping                                             5.4s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠼ Container client   Stopping                                             5.5s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠴ Container client   Stopping                                             5.6s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠦ Container client   Stopping                                             5.7s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠧ Container client   Stopping                                             5.8s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠇ Container client   Stopping                                             5.9s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠏ Container client   Stopping                                             6.0s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠋ Container client   Stopping                                             6.1s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠙ Container client   Stopping                                             6.2s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠹ Container client   Stopping                                             6.3s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠸ Container client   Stopping                                             6.4s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠼ Container client   Stopping                                             6.5s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠴ Container client   Stopping                                             6.6s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠦ Container client   Stopping                                             6.7s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠧ Container client   Stopping                                             6.8s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠇ Container client   Stopping                                             6.9s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠏ Container client   Stopping                                             7.0s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠋ Container client   Stopping                                             7.1s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠙ Container client   Stopping                                             7.2s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠹ Container client   Stopping                                             7.3s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠸ Container client   Stopping                                             7.4s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠼ Container client   Stopping                                             7.5s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠴ Container client   Stopping                                             7.6s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠦ Container client   Stopping                                             7.7s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠧ Container client   Stopping                                             7.8s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠇ Container client   Stopping                                             7.9s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠏ Container client   Stopping                                             8.0s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠋ Container client   Stopping                                             8.1s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠙ Container client   Stopping                                             8.2s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠹ Container client   Stopping                                             8.3s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠸ Container client   Stopping                                             8.4s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠼ Container client   Stopping                                             8.5s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠴ Container client   Stopping                                             8.6s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠦ Container client   Stopping                                             8.7s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠧ Container client   Stopping                                             8.8s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠇ Container client   Stopping                                             8.9s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠏ Container client   Stopping                                             9.0s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠋ Container client   Stopping                                             9.1s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠙ Container client   Stopping                                             9.2s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠹ Container client   Stopping                                             9.3s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠸ Container client   Stopping                                             9.4s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠼ Container client   Stopping                                             9.5s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠴ Container client   Stopping                                             9.6s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠦ Container client   Stopping                                             9.7s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠧ Container client   Stopping                                             9.8s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠇ Container client   Stopping                                             9.9s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠏ Container client   Stopping                                            10.0s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠋ Container client   Stopping                                            10.1s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠙ Container client   Stopping                                            10.2s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠹ Container client   Stopping                                            10.3s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠸ Container client   Stopping                                            10.4s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 1/2
#  ⠼ Container client   Stopping                                            10.5s
#  ✔ Container adminer  Removed                                              0.4s
# [+] Running 2/2
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠋ Container server   Stopping                                             0.0s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠙ Container server   Stopping                                             0.1s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠹ Container server   Stopping                                             0.2s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠸ Container server   Stopping                                             0.3s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠼ Container server   Stopping                                             0.4s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠴ Container server   Stopping                                             0.5s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠦ Container server   Stopping                                             0.6s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠧ Container server   Stopping                                             0.7s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠇ Container server   Stopping                                             0.8s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠏ Container server   Stopping                                             0.9s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠋ Container server   Stopping                                             1.0s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠙ Container server   Stopping                                             1.1s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠹ Container server   Stopping                                             1.2s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠸ Container server   Stopping                                             1.3s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠼ Container server   Stopping                                             1.4s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠴ Container server   Stopping                                             1.5s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠦ Container server   Stopping                                             1.6s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠧ Container server   Stopping                                             1.7s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠇ Container server   Stopping                                             1.8s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠏ Container server   Stopping                                             1.9s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠋ Container server   Stopping                                             2.0s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠙ Container server   Stopping                                             2.1s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠹ Container server   Stopping                                             2.2s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠸ Container server   Stopping                                             2.3s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠼ Container server   Stopping                                             2.4s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠴ Container server   Stopping                                             2.5s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠦ Container server   Stopping                                             2.6s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠧ Container server   Stopping                                             2.7s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠇ Container server   Stopping                                             2.8s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠏ Container server   Stopping                                             2.9s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠋ Container server   Stopping                                             3.0s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠙ Container server   Stopping                                             3.1s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠹ Container server   Stopping                                             3.2s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠸ Container server   Stopping                                             3.3s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠼ Container server   Stopping                                             3.4s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠴ Container server   Stopping                                             3.5s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠦ Container server   Stopping                                             3.6s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠧ Container server   Stopping                                             3.7s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠇ Container server   Stopping                                             3.8s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠏ Container server   Stopping                                             3.9s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠋ Container server   Stopping                                             4.0s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠙ Container server   Stopping                                             4.1s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠹ Container server   Stopping                                             4.2s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠸ Container server   Stopping                                             4.3s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠼ Container server   Stopping                                             4.4s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠴ Container server   Stopping                                             4.5s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠦ Container server   Stopping                                             4.6s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠧ Container server   Stopping                                             4.7s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠇ Container server   Stopping                                             4.8s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠏ Container server   Stopping                                             4.9s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠋ Container server   Stopping                                             5.0s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠙ Container server   Stopping                                             5.1s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠹ Container server   Stopping                                             5.2s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠸ Container server   Stopping                                             5.3s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠼ Container server   Stopping                                             5.4s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠴ Container server   Stopping                                             5.5s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠦ Container server   Stopping                                             5.6s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠧ Container server   Stopping                                             5.7s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠇ Container server   Stopping                                             5.8s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠏ Container server   Stopping                                             5.9s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠋ Container server   Stopping                                             6.0s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠙ Container server   Stopping                                             6.1s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠹ Container server   Stopping                                             6.2s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠸ Container server   Stopping                                             6.3s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠼ Container server   Stopping                                             6.4s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠴ Container server   Stopping                                             6.5s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠦ Container server   Stopping                                             6.6s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠧ Container server   Stopping                                             6.7s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠇ Container server   Stopping                                             6.8s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠏ Container server   Stopping                                             6.9s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠋ Container server   Stopping                                             7.0s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠙ Container server   Stopping                                             7.1s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠹ Container server   Stopping                                             7.2s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠸ Container server   Stopping                                             7.3s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠼ Container server   Stopping                                             7.4s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠴ Container server   Stopping                                             7.5s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠦ Container server   Stopping                                             7.6s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠧ Container server   Stopping                                             7.7s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠇ Container server   Stopping                                             7.8s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠏ Container server   Stopping                                             7.9s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠋ Container server   Stopping                                             8.0s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠙ Container server   Stopping                                             8.1s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠹ Container server   Stopping                                             8.2s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠸ Container server   Stopping                                             8.3s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠼ Container server   Stopping                                             8.4s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠴ Container server   Stopping                                             8.5s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠦ Container server   Stopping                                             8.6s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠧ Container server   Stopping                                             8.7s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠇ Container server   Stopping                                             8.8s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠏ Container server   Stopping                                             8.9s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠋ Container server   Stopping                                             9.0s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠙ Container server   Stopping                                             9.1s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠹ Container server   Stopping                                             9.2s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠸ Container server   Stopping                                             9.3s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠼ Container server   Stopping                                             9.4s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠴ Container server   Stopping                                             9.5s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠦ Container server   Stopping                                             9.6s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠧ Container server   Stopping                                             9.7s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠇ Container server   Stopping                                             9.8s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠏ Container server   Stopping                                             9.9s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠋ Container server   Stopping                                            10.0s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠙ Container server   Stopping                                            10.1s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠹ Container server   Stopping                                            10.2s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠸ Container server   Stopping                                            10.3s
# [+] Running 2/3
#  ✔ Container client   Removed                                             10.6s
#  ✔ Container adminer  Removed                                              0.4s
#  ⠼ Container server   Stopping                                            10.4s
# [+] Running 3/3
#  ✔ Container client    Removed                                            10.6s
#  ✔ Container adminer   Removed                                             0.4s
#  ✔ Container server    Removed                                            10.4s
#  ⠋ Container postgres  Stopping                                            0.1s
# [+] Running 3/4
#  ✔ Container client    Removed                                            10.6s
#  ✔ Container adminer   Removed                                             0.4s
#  ✔ Container server    Removed                                            10.4s
#  ⠙ Container postgres  Stopping                                            0.2s
# [+] Running 3/4
#  ✔ Container client    Removed                                            10.6s
#  ✔ Container adminer   Removed                                             0.4s
#  ✔ Container server    Removed                                            10.4s
#  ⠹ Container postgres  Stopping                                            0.3s
# [+] Running 3/4
#  ✔ Container client    Removed                                            10.6s
#  ✔ Container adminer   Removed                                             0.4s
#  ✔ Container server    Removed                                            10.4s
#  ⠸ Container postgres  Stopping                                            0.4s
# [+] Running 6/4
#  ✔ Container client                 Removed                               10.6s
#  ✔ Container adminer                Removed                                0.4s
#  ✔ Container server                 Removed                               10.4s
#  ✔ Container postgres               Removed                                0.4s
#  ✔ Image loadtesting-server:latest  R...                                   0.0s
#  ✔ Image loadtesting-client:latest  R...                                   0.0s
#  ⠋ Network loadtesting_loadtesting  R...                                   0.0s
# [+] Running 6/7
#  ✔ Container client                 Removed                               10.6s
#  ✔ Container adminer                Removed                                0.4s
#  ✔ Container server                 Removed                               10.4s
#  ✔ Container postgres               Removed                                0.4s
#  ✔ Image loadtesting-server:latest  R...                                   0.0s
#  ✔ Image loadtesting-client:latest  R...                                   0.0s
#  ⠙ Network loadtesting_loadtesting  R...                                   0.1s
# [+] Running 6/7
#  ✔ Container client                 Removed                               10.6s
#  ✔ Container adminer                Removed                                0.4s
#  ✔ Container server                 Removed                               10.4s
#  ✔ Container postgres               Removed                                0.4s
#  ✔ Image loadtesting-server:latest  R...                                   0.0s
#  ✔ Image loadtesting-client:latest  R...                                   0.0s
#  ⠹ Network loadtesting_loadtesting  R...                                   0.2s
# [+] Running 7/7
#  ✔ Container client                 Removed                               10.6s
#  ✔ Container adminer                Removed                                0.4s
#  ✔ Container server                 Removed                               10.4s
#  ✔ Container postgres               Removed                                0.4s
#  ✔ Image loadtesting-server:latest  R...                                   0.0s
#  ✔ Image loadtesting-client:latest  R...                                   0.0s
#  ✔ Network loadtesting_loadtesting  R...                                   0.2s
